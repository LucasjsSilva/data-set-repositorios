# %% [markdown]
# # Imports

# %%
import pandas as pd

# %%
# Import the dataset into a pandas DataFrame
df = pd.read_csv('../dados/github_repos_completos.csv')

# Display dataset information
print('Dataset de Repositórios do GitHub contendo:')
print(f'{df.shape[0]} registros')
print(f'{df.shape[1]} colunas\n')

df.head()
# Out:
#                    name                 owner   stars  forks language  \
# 0           public-apis           public-apis  337982  35685   Python
# 1  system-design-primer           donnemartin  297377  49424   Python
# 2        awesome-python                 vinta  241676  25593   Python
# 3                Python         TheAlgorithms  199952  46665   Python
# 4               AutoGPT  Significant-Gravitas  174836  45629   Python
#
#              created_at            updated_at  size_kb  watchers_count  \
# 0  2016-03-20T23:49:42Z  2025-04-28T01:10:29Z     5030          337982
# 1  2017-02-26T16:15:28Z  2025-04-28T01:01:03Z    11220          297377
# 2  2014-06-27T21:00:06Z  2025-04-28T01:08:03Z     6769          241676
# 3  2016-07-16T09:44:01Z  2025-04-28T01:08:49Z    15239          199952
# 4  2023-03-16T09:21:07Z  2025-04-28T00:50:10Z   241531          174836
#
#    open_issues    owner_type  owner_public_repos    owner_location  \
# 0          452  Organization                   1               NaN
# 1          489          User                  27  Washington, D.C.
# 2          473          User                  20            Taiwan
# 3          371  Organization                  44             India
# 4          207  Organization                  21               NaN
#
#    subscribers_count  last_year_commits  contributors  closed_issues  \
# 0                 30                  5             1             30
# 1                 30                  3             1             14
# 2                 30                  3             1             23
# 3                 30                178             1             30
# 4                 30               1392             1             30
#
#    pull_requests
# 0             30
# 1             30
# 2             30
# 3             30
# 4             30

# %% [markdown]
# # Data Dictionary

# %%
# Display the data types of each column in the DataFrame
df.dtypes
# Out:
# name                  object
# owner                 object
# stars                  int64
# forks                  int64
# language              object
# created_at            object
# updated_at            object
# size_kb                int64
# watchers_count         int64
# open_issues            int64
# owner_type            object
# owner_public_repos     int64
# owner_location        object
# subscribers_count      int64
# last_year_commits      int64
# contributors           int64
# closed_issues          int64
# pull_requests          int64
# dtype: object

# %%
# Create a DataFrame to serve as a data dictionary, showing each attribute's name and its data type.
dict_df = pd.DataFrame({
    'Nome do Atributo': df.dtypes.index,
    'Tipo do Valor': df.dtypes.values.astype(str),
})

# %%
dict_df
# Out:
#       Nome do Atributo Tipo do Valor
# 0                 name        object
# 1                owner        object
# 2                stars         int64
# 3                forks         int64
# 4             language        object
# 5           created_at        object
# 6           updated_at        object
# 7              size_kb         int64
# 8       watchers_count         int64
# 9          open_issues         int64
# 10          owner_type        object
# 11  owner_public_repos         int64
# 12      owner_location        object
# 13   subscribers_count         int64
# 14   last_year_commits         int64
# 15        contributors         int64
# 16       closed_issues         int64
# 17       pull_requests         int64

# %%
# Helper function to classify a data type as 'Numérico' (Numeric) or 'Categórico' (Categorical).
def classify_format(dtype):
    if dtype == 'int64' or dtype == 'float64':
        return 'Numérico'
    else:
        return 'Categórico'

# %%
# Apply the classification function to determine if each attribute is 'Numérico' or 'Categórico'.
dict_df['Tipo do Formato'] = dict_df['Tipo do Valor'].apply(classify_format)

# %%
# Add descriptions for each attribute to the data dictionary.
descricoes = [
    "Nome do repositório",
    "Login do usuário/organização dono",
    "Número de estrelas",
    "Número de forks",
    "Linguagem principal do projeto",
    "Data de criação do repositório (UTC)",
    "Data da última atualização",
    "Tamanho aproximado do repositório em KB",
    "Usuários acompanhando o repositório",
    "Issues abertas no momento",
    "Tipo do dono (User ou Organization)",
    "Quantidade de repositórios públicos do dono",
    "Localização geográfica declarada no perfil (opcional)",
    "Inscritos no repositório",
    "Quantidade de commits realizados nos últimos 12 meses",
    "Número de contribuidores únicos",
    "Issues fechadas nos últimos 6 meses",
    "Quantidade total de pull requests (abertos + fechados)"
]

dict_df['Descrição do Atributo'] = descricoes

# %%
# Refine 'Tipo do Valor' for clarity and accuracy in the data dictionary.
# 'object' is replaced with 'string', and specific date columns are set to 'datetime'.

dict_df['Tipo do Valor'] = dict_df['Tipo do Valor'].replace('object', 'string')
dict_df.loc[dict_df['Nome do Atributo'].isin(['created_at', 'updated_at']), 'Tipo do Valor'] = 'datetime'

# %%
dict_df
# Out:
#       Nome do Atributo Tipo do Valor Tipo do Formato  \
# 0                 name        object      Categórico
# 1                owner        object      Categórico
# 2                stars         int64        Numérico
# 3                forks         int64        Numérico
# 4             language        object      Categórico
# 5           created_at        object      Categórico
# 6           updated_at        object      Categórico
# 7              size_kb         int64        Numérico
# 8       watchers_count         int64        Numérico
# 9          open_issues         int64        Numérico
# 10          owner_type        object      Categórico
# 11  owner_public_repos         int64        Numérico
# 12      owner_location        object      Categórico
# 13   subscribers_count         int64        Numérico
# 14   last_year_commits         int64        Numérico
# 15        contributors         int64        Numérico
# 16       closed_issues         int64        Numérico
# 17       pull_requests         int64        Numérico
#
#                                 Descrição do Atributo
# 0                                 Nome do repositório
# 1                   Login do usuário/organização dono
# 2                                  Número de estrelas
# 3                                     Número de forks
# 4                      Linguagem principal do projeto
# 5                Data de criação do repositório (UTC)
# 6                          Data da última atualização
# 7             Tamanho aproximado do repositório em KB
# 8                 Usuários acompanhando o repositório
# 9                           Issues abertas no momento
# 10                Tipo do dono (User ou Organization)
# 11        Quantidade de repositórios públicos do dono
# 12  Localização geográfica declarada no perfil (op...
# 13                           Inscritos no repositório
# 14  Quantidade de commits realizados nos últimos 1...
# 15                    Número de contribuidores únicos
# 16                Issues fechadas nos últimos 6 meses
# 17  Quantidade total de pull requests (abertos + f...

# %%
# Save the created data dictionary DataFrame to a CSV file.
dict_df.to_csv('../dados/req2.csv', index=False)
